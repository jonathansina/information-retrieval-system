# %%
import pandas as pd

# %%
training_df = pd.read_csv('../data/augmented_dataset.csv')
evaluation_df = pd.read_csv('../data/test_digikala_faq.csv')

# %%
training_df
# Out:
#                                               question  \
# 0     فرآیند ثبت نام آدرس خود در حساب کاربری شما چیست؟
# 1    آیا می توانید نحوه اضافه کردن آدرس خود را به ح...
# 2    چگونه می توانید آدرس آدرس خود را به حساب خود ا...
# 3    آیا راهی برای اضافه کردن آدرس خود به حساب خود ...
# 4    هنگام افزودن آدرس خود به حساب خود ، مراحل دنبا...
# ..                                                 ...
# 490               تجدید خودکار چگونه از من سود می برد؟
# 491  از چه راههایی می تواند تجدید خودکار به من سود ...
# 492                  مزایای تجدید خودکار برای من چیست؟
# 493        تجدید خودکار چه مزایایی به من ارائه می دهد؟
# 494              چرا باید از تجدید خودکار استفاده کنم؟
#
#                                                 answer        category
# 0    پس از تکمیل اطلاعات کاربری خود به قسمت نشانی ه...  ورود و ثبت نام
# 1    پس از تکمیل اطلاعات کاربری خود به قسمت نشانی ه...  ورود و ثبت نام
# 2    پس از تکمیل اطلاعات کاربری خود به قسمت نشانی ه...  ورود و ثبت نام
# ...

# %%
print(training_df["category"].unique())
# Out:
# ['ورود و ثبت نام' 'روند ثبت سفارش' 'پیگیری ارسال سفارش' 'بازگرداندن کالا'
#  'کد تخفیف و کارت هدیه' 'سوپرمارکت' 'تعهد به شفافیت' 'دیجی\u200cپی'
#  'دیجی\u200cکلاب' 'دیجی\u200cپلاس']

# %%
print(evaluation_df["category"].unique())
# Out:
# ['روند ثبت سفارش' 'پیگیری ارسال سفارش' 'دیجی\u200cپلاس' 'دیجی\u200cکلاب'
#  'تعهد به شفافیت' 'ورود و ثبت نام' 'سوپرمارکت' 'دیجی\u200cپی'
#  'کد تخفیف و کارت هدیه' 'بازگرداندن کالا']

# %%
evaluation_df
# Out:
#                                                 query              category
# 0       چگونه می‌توانم رمز عبور حسابم را بازیابی کنم؟        روند ثبت سفارش
# 1   آیا امکان تغییر آدرس تحویل بعد از ثبت سفارش وج...    پیگیری ارسال سفارش
# 2   چگونه می‌توانم از تخفیف‌های ویژه دیجی‌پلاس است...             دیجی‌پلاس
# 3   آیا ارسال رایگان برای همه محصولات امکان‌پذیر است؟             دیجی‌کلاب
# 4                 چطور می‌توانم سفارش خود را لغو کنم؟             دیجی‌پلاس
# 5      زمان تقریبی تحویل کالاهای سوپرمارکتی چقدر است؟             دیجی‌کلاب
# 6   چگونه می‌توانم محصولات مورد علاقه خود را به لی...        تعهد به شفافیت
# 7           در صورت تأخیر در ارسال، چگونه پیگیری کنم؟        روند ثبت سفارش
# 8   آیا امکان پرداخت در محل برای سفارشات من وجود د...        ورود و ثبت نام
# 9   چگونه می‌توانم کوپن تخفیف را در هنگام خرید اعم...        روند ثبت سفارش
# 10       آیا کالاهای خریداری‌شده را می‌توانم پس بدهم؟             سوپرمارکت
# ...
